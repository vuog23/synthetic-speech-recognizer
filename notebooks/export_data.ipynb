# %%
import os
os.chdir('..')

# %%
from src.features.mel_spectrogram import wav2melspec

# %%
train_path = r"D:\Project\Synthetic Speech Recognizer\datasets\raw\for-norm\for-norm\training"
train_save_path = r"D:\Project\Synthetic Speech Recognizer\datasets\processed\train.pt"

wav2melspec(train_path, train_save_path)

# %%
test_path = r"D:\Project\Synthetic Speech Recognizer\datasets\raw\for-norm\for-norm\testing"
test_save_path = r"D:\Project\Synthetic Speech Recognizer\datasets\processed\test.pt"

wav2melspec(test_path, test_save_path)

# %%
val_path = r"D:\Project\Synthetic Speech Recognizer\datasets\raw\for-norm\for-norm\validation"
val_save_path = r"D:\Project\Synthetic Speech Recognizer\datasets\processed\val.pt"

wav2melspec(val_path, val_save_path)
