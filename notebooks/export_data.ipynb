# %%
import os
os.chdir('..')

# %%
from src.features.mel_spectrogram import AudioPreprocessor
from src.data.for_data import wav2melspec

# %%
root_path = r"D:\Project\Synthetic Speech Recognizer\datasets\raw\for-norm\for-norm\training"
output_dir = r"D:\Project\Synthetic Speech Recognizer\datasets\processed\train.pt"
wav2melspec(root_path, output_dir, AudioPreprocessor())
# Out:
# Processing real:   4%|▎         | 956/26941 [00:12<03:54, 111.03it/s]
# Error file11064.wav_16k.wav_norm.wav_mono.wav_silence.wav: zero-size array to reduction operation maximum which has no identity
# Processing real:  18%|█▊        | 4724/26941 [00:41<02:45, 134.35it/s]
# Error file15440.wav_16k.wav_norm.wav_mono.wav_silence.wav: zero-size array to reduction operation maximum which has no identity
# ...
# Processing fake: 100%|██████████| 26927/26927 [02:14<00:00, 200.50it/s]
# Saved 53866 samples to D:\Project\Synthetic Speech Recognizer\datasets\processed\train.pt

# %%
root_path = r"D:\Project\Synthetic Speech Recognizer\datasets\raw\for-norm\for-norm\testing"
output_dir = r"D:\Project\Synthetic Speech Recognizer\datasets\processed\test.pt"
wav2melspec(root_path, output_dir, AudioPreprocessor())
# Out:
# ...
# Processing fake: 100%|██████████| 2370/2370 [00:11<00:00, 204.63it/s]
# Saved 4634 samples to D:\Project\Synthetic Speech Recognizer\datasets\processed\test.pt

# %%
root_path = r"D:\Project\Synthetic Speech Recognizer\datasets\raw\for-norm\for-norm\validation"
output_dir = r"D:\Project\Synthetic Speech Recognizer\datasets\processed\val.pt"
wav2melspec(root_path, output_dir, AudioPreprocessor())
# Out:
# ...
# Processing fake: 100%|██████████| 5398/5398 [00:31<00:00, 170.69it/s]
# Saved 10798 samples to D:\Project\Synthetic Speech Recognizer\datasets\processed\val.pt
