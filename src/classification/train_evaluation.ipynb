# %%
import os
os.chdir('..')
os.chdir('..')

# %%
from src.classification.training.trainer import Trainer
from src.classification.evaluation.evaluator import Evaluator

# %%
data_root = r"D:\Project\Synthetic Speech Recognizer\datasets\ASVLibri"

# %%
trainer = Trainer(
    model_path="timm/convnextv2_base.fcmae_ft_in1k",

    data_root=data_root,

    in_chans=1,
    num_classes=2,

    batch_size=32,
    lr=1e-4,
    drop_path_rate=0.0,
    max_grad_norm=1.0,
    use_class_weights=True,
    check_finite=True,

    epochs=10,
)

trainer.train(
    save_path="best_model.pt",
    history_path="history.csv",
)

# %%
evaluator = Evaluator(
    model_path="timm/convnextv2_base.fcmae_ft_in1k",
    weight_path=r"D:\Project\Synthetic Speech Recognizer\models\convnext_tiny\best_model.pt",

    in_chans=1,
    num_classes=2,

    batch_size=32,
)

results = evaluator.evaluate(
    data_root=data_root,
    split="test"
)

print(results)
# Out:
# d:\Project\Synthetic Speech Recognizer\src\classification\evaluation\evaluator.py:58: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 evaluator = Evaluator(
#       2     model_path="timm/convnextv2_base.fcmae_ft_in1k",
#       3     weight_path=r"D:\Project\Synthetic Speech Recognizer\models\convnext_tiny\best_model.pt",
#       4
#       5     in_chans=1,
#       6     num_classes=2,
#       7
#       8     batch_size=32,
#       9 )
#      11 results = evaluator.evaluate(
#      12     data_root=data_root,
#      13     split="test"
#      14 )
#      16 print(results)
#
# File d:\Project\Synthetic Speech Recognizer\src\classification\evaluation\evaluator.py:63, in Evaluator.__init__(self, model_path, weight_path, in_chans, num_classes, batch_size, num_workers)
#      51 self.model = timm.create_model(
#      52     model_path,
#      53     pretrained=False,
#      54     in_chans=in_chans,
#      55     num_classes=num_classes,
#      56 ).to(self.device)
#      58 state_dict = torch.load(
#      59     weight_path,
#      60     map_location=self.device,
#      61 )
# ---> 63 self.model.load_state_dict(state_dict)
#      65 self.model.eval()
#      67 print(f"Evaluator device: {self.device}")
#
# File d:\anaconda3\envs\pytorchgpu\Lib\site-packages\torch\nn\modules\module.py:2584, in Module.load_state_dict(self, state_dict, strict, assign)
#    2576         error_msgs.insert(
#    2577             0,
#    2578             "Missing key(s) in state_dict: {}. ".format(
#    2579                 ", ".join(f'"{k}"' for k in missing_keys)
#    2580             ),
#    2581         )
#    2583 if len(error_msgs) > 0:
# -> 2584     raise RuntimeError(
#    2585         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2586             self.__class__.__name__, "\n\t".join(error_msgs)
#    2587         )
#    2588     )
#    2589 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for ConvNeXt:
# 	Missing key(s) in state_dict: "stages.0.blocks.0.mlp.grn.weight", "stages.0.blocks.0.mlp.grn.bias", "stages.0.blocks.1.mlp.grn.weight", "stages.0.blocks.1.mlp.grn.bias", "stages.0.blocks.2.mlp.grn.weight", "stages.0.blocks.2.mlp.grn.bias", "stages.1.blocks.0.mlp.grn.weight", "stages.1.blocks.0.mlp.grn.bias", "stages.1.blocks.1.mlp.grn.weight", "stages.1.blocks.1.mlp.grn.bias", "stages.1.blocks.2.mlp.grn.weight", "stages.1.blocks.2.mlp.grn.bias", "stages.2.blocks.0.mlp.grn.weight", "stages.2.blocks.0.mlp.grn.bias", "stages.2.blocks.1.mlp.grn.weight", "stages.2.blocks.1.mlp.grn.bias", "stages.2.blocks.2.mlp.grn.weight", "stages.2.blocks.2.mlp.grn.bias", "stages.2.blocks.3.mlp.grn.weight", "stages.2.blocks.3.mlp.grn.bias", "stages.2.blocks.4.mlp.grn.weight", "stages.2.blocks.4.mlp.grn.bias", "stages.2.blocks.5.mlp.grn.weight", "stages.2.blocks.5.mlp.grn.bias", "stages.2.blocks.6.mlp.grn.weight", "stages.2.blocks.6.mlp.grn.bias", "stages.2.blocks.7.mlp.grn.weight", "stages.2.blocks.7.mlp.grn.bias", "stages.2.blocks.8.mlp.grn.weight", "stages.2.blocks.8.mlp.grn.bias", "stages.2.blocks.9.conv_dw.weight", "stages.2.blocks.9.conv_dw.bias", "stages.2.blocks.9.norm.weight", "stages.2.blocks.9.norm.bias", "stages.2.blocks.9.mlp.fc1.weight", "stages.2.blocks.9.mlp.fc1.bias", "stages.2.blocks.9.mlp.grn.weight", "stages.2.blocks.9.mlp.grn.bias", "stages.2.blocks.9.mlp.fc2.weight", "stages.2.blocks.9.mlp.fc2.bias", "stages.2.blocks.10.conv_dw.weight", "stages.2.blocks.10.conv_dw.bias", "stages.2.blocks.10.norm.weight", "stages.2.blocks.10.norm.bias", "stages.2.blocks.10.mlp.fc1.weight", "stages.2.blocks.10.mlp.fc1.bias", "stages.2.blocks.10.mlp.grn.weight", "stages.2.blocks.10.mlp.grn.bias", "stages.2.blocks.10.mlp.fc2.weight", "stages.2.blocks.10.mlp.fc2.bias", "stages.2.blocks.11.conv_dw.weight", "stages.2.blocks.11.conv_dw.bias", "stages.2.blocks.11.norm.weight", "stages.2.blocks.11.norm.bias", "stages.2.blocks.11.mlp.fc1.weight", "stages.2.blocks.11.mlp.fc1.bias", "stages.2.blocks.11.mlp.grn.weight", "stages.2.blocks.11.mlp.grn.bias", "stages.2.blocks.11.mlp.fc2.weight", "stages.2.blocks.11.mlp.fc2.bias", "stages.2.blocks.12.conv_dw.weight", "stages.2.blocks.12.conv_dw.bias", "stages.2.blocks.12.norm.weight", "stages.2.blocks.12.norm.bias", "stages.2.blocks.12.mlp.fc1.weight", "stages.2.blocks.12.mlp.fc1.bias", "stages.2.blocks.12.mlp.grn.weight", "stages.2.blocks.12.mlp.grn.bias", "stages.2.blocks.12.mlp.fc2.weight", "stages.2.blocks.12.mlp.fc2.bias", "stages.2.blocks.13.conv_dw.weight", "stages.2.blocks.13.conv_dw.bias", "stages.2.blocks.13.norm.weight", "stages.2.blocks.13.norm.bias", "stages.2.blocks.13.mlp.fc1.weight", "stages.2.blocks.13.mlp.fc1.bias", "stages.2.blocks.13.mlp.grn.weight", "stages.2.blocks.13.mlp.grn.bias", "stages.2.blocks.13.mlp.fc2.weight", "stages.2.blocks.13.mlp.fc2.bias", "stages.2.blocks.14.conv_dw.weight", "stages.2.blocks.14.conv_dw.bias", "stages.2.blocks.14.norm.weight", "stages.2.blocks.14.norm.bias", "stages.2.blocks.14.mlp.fc1.weight", "stages.2.blocks.14.mlp.fc1.bias", "stages.2.blocks.14.mlp.grn.weight", "stages.2.blocks.14.mlp.grn.bias", "stages.2.blocks.14.mlp.fc2.weight", "stages.2.blocks.14.mlp.fc2.bias", "stages.2.blocks.15.conv_dw.weight", "stages.2.blocks.15.conv_dw.bias", "stages.2.blocks.15.norm.weight", "stages.2.blocks.15.norm.bias", "stages.2.blocks.15.mlp.fc1.weight", "stages.2.blocks.15.mlp.fc1.bias", "stages.2.blocks.15.mlp.grn.weight", "stages.2.blocks.15.mlp.grn.bias", "stages.2.blocks.15.mlp.fc2.weight", "stages.2.blocks.15.mlp.fc2.bias", "stages.2.blocks.16.conv_dw.weight", "stages.2.blocks.16.conv_dw.bias", "stages.2.blocks.16.norm.weight", "stages.2.blocks.16.norm.bias", "stages.2.blocks.16.mlp.fc1.weight", "stages.2.blocks.16.mlp.fc1.bias", "stages.2.blocks.16.mlp.grn.weight", "stages.2.blocks.16.mlp.grn.bias", "stages.2.blocks.16.mlp.fc2.weight", "stages.2.blocks.16.mlp.fc2.bias", "stages.2.blocks.17.conv_dw.weight", "stages.2.blocks.17.conv_dw.bias", "stages.2.blocks.17.norm. ...
# 	Unexpected key(s) in state_dict: "stages.0.blocks.0.gamma", "stages.0.blocks.1.gamma", "stages.0.blocks.2.gamma", "stages.1.blocks.0.gamma", "stages.1.blocks.1.gamma", "stages.1.blocks.2.gamma", "stages.2.blocks.0.gamma", "stages.2.blocks.1.gamma", "stages.2.blocks.2.gamma", "stages.2.blocks.3.gamma", "stages.2.blocks.4.gamma", "stages.2.blocks.5.gamma", "stages.2.blocks.6.gamma", "stages.2.blocks.7.gamma", "stages.2.blocks.8.gamma", "stages.3.blocks.0.gamma", "stages.3.blocks.1.gamma", "stages.3.blocks.2.gamma", "norm_pre.weight", "norm_pre.bias".
# 	size mismatch for stem.0.weight: copying a param with shape torch.Size([96, 1, 4, 4]) from checkpoint, the shape in current model is torch.Size([128, 1, 4, 4]).
# 	size mismatch for stem.0.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stem.1.weight: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stem.1.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.0.conv_dw.weight: copying a param with shape torch.Size([96, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([128, 1, 7, 7]).
# 	size mismatch for stages.0.blocks.0.conv_dw.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.0.norm.weight: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.0.norm.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.0.mlp.fc1.weight: copying a param with shape torch.Size([384, 96, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 128]).
# 	size mismatch for stages.0.blocks.0.mlp.fc1.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.0.blocks.0.mlp.fc2.weight: copying a param with shape torch.Size([96, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 512]).
# 	size mismatch for stages.0.blocks.0.mlp.fc2.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.1.conv_dw.weight: copying a param with shape torch.Size([96, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([128, 1, 7, 7]).
# 	size mismatch for stages.0.blocks.1.conv_dw.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.1.norm.weight: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.1.norm.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.1.mlp.fc1.weight: copying a param with shape torch.Size([384, 96, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 128]).
# 	size mismatch for stages.0.blocks.1.mlp.fc1.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.0.blocks.1.mlp.fc2.weight: copying a param with shape torch.Size([96, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 512]).
# 	size mismatch for stages.0.blocks.1.mlp.fc2.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.2.conv_dw.weight: copying a param with shape torch.Size([96, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([128, 1, 7, 7]).
# 	size mismatch for stages.0.blocks.2.conv_dw.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.2.norm.weight: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.2.norm.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.0.blocks.2.mlp.fc1.weight: copying a param with shape torch.Size([384, 96, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 128]).
# 	size mismatch for stages.0.blocks.2.mlp.fc1.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.0.blocks.2.mlp.fc2.weight: copying a param with shape torch.Size([96, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 512]).
# 	size mismatch for stages.0.blocks.2.mlp.fc2.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.1.downsample.0.weight: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.1.downsample.0.bias: copying a param with shape torch.Size([96]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for stages.1.downsample.1.weight: copying a param with shape torch.Size([192, 96, 2, 2]) from checkpoint, the shape in current model is torch.Size([256, 128, 2, 2]).
# 	size mismatch for stages.1.downsample.1.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.0.conv_dw.weight: copying a param with shape torch.Size([192, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([256, 1, 7, 7]).
# 	size mismatch for stages.1.blocks.0.conv_dw.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.0.norm.weight: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.0.norm.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.0.mlp.fc1.weight: copying a param with shape torch.Size([768, 192, 1, 1]) from checkpoint, the shape in current model is torch.Size([1024, 256]).
# 	size mismatch for stages.1.blocks.0.mlp.fc1.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.1.blocks.0.mlp.fc2.weight: copying a param with shape torch.Size([192, 768, 1, 1]) from checkpoint, the shape in current model is torch.Size([256, 1024]).
# 	size mismatch for stages.1.blocks.0.mlp.fc2.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.1.conv_dw.weight: copying a param with shape torch.Size([192, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([256, 1, 7, 7]).
# 	size mismatch for stages.1.blocks.1.conv_dw.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.1.norm.weight: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.1.norm.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.1.mlp.fc1.weight: copying a param with shape torch.Size([768, 192, 1, 1]) from checkpoint, the shape in current model is torch.Size([1024, 256]).
# 	size mismatch for stages.1.blocks.1.mlp.fc1.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.1.blocks.1.mlp.fc2.weight: copying a param with shape torch.Size([192, 768, 1, 1]) from checkpoint, the shape in current model is torch.Size([256, 1024]).
# 	size mismatch for stages.1.blocks.1.mlp.fc2.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.2.conv_dw.weight: copying a param with shape torch.Size([192, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([256, 1, 7, 7]).
# 	size mismatch for stages.1.blocks.2.conv_dw.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.2.norm.weight: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.2.norm.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.1.blocks.2.mlp.fc1.weight: copying a param with shape torch.Size([768, 192, 1, 1]) from checkpoint, the shape in current model is torch.Size([1024, 256]).
# 	size mismatch for stages.1.blocks.2.mlp.fc1.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.1.blocks.2.mlp.fc2.weight: copying a param with shape torch.Size([192, 768, 1, 1]) from checkpoint, the shape in current model is torch.Size([256, 1024]).
# 	size mismatch for stages.1.blocks.2.mlp.fc2.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.2.downsample.0.weight: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.2.downsample.0.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for stages.2.downsample.1.weight: copying a param with shape torch.Size([384, 192, 2, 2]) from checkpoint, the shape in current model is torch.Size([512, 256, 2, 2]).
# 	size mismatch for stages.2.downsample.1.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.0.conv_dw.weight: copying a param with shape torch.Size([384, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([512, 1, 7, 7]).
# 	size mismatch for stages.2.blocks.0.conv_dw.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.0.norm.weight: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.0.norm.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.0.mlp.fc1.weight: copying a param with shape torch.Size([1536, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([2048, 512]).
# 	size mismatch for stages.2.blocks.0.mlp.fc1.bias: copying a param with shape torch.Size([1536]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for stages.2.blocks.0.mlp.fc2.weight: copying a param with shape torch.Size([384, 1536, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 2048]).
# 	size mismatch for stages.2.blocks.0.mlp.fc2.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.1.conv_dw.weight: copying a param with shape torch.Size([384, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([512, 1, 7, 7]).
# 	size mismatch for stages.2.blocks.1.conv_dw.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.1.norm.weight: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.1.norm.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.1.mlp.fc1.weight: copying a param with shape torch.Size([1536, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([2048, 512]).
# 	size mismatch for stages.2.blocks.1.mlp.fc1.bias: copying a param with shape torch.Size([1536]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for stages.2.blocks.1.mlp.fc2.weight: copying a param with shape torch.Size([384, 1536, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 2048]).
# 	size mismatch for stages.2.blocks.1.mlp.fc2.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.2.conv_dw.weight: copying a param with shape torch.Size([384, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([512, 1, 7, 7]).
# 	size mismatch for stages.2.blocks.2.conv_dw.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.2.norm.weight: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.2.norm.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.2.mlp.fc1.weight: copying a param with shape torch.Size([1536, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([2048, 512]).
# 	size mismatch for stages.2.blocks.2.mlp.fc1.bias: copying a param with shape torch.Size([1536]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for stages.2.blocks.2.mlp.fc2.weight: copying a param with shape torch.Size([384, 1536, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 2048]).
# 	size mismatch for stages.2.blocks.2.mlp.fc2.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.3.conv_dw.weight: copying a param with shape torch.Size([384, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([512, 1, 7, 7]).
# 	size mismatch for stages.2.blocks.3.conv_dw.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.3.norm.weight: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.3.norm.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.3.mlp.fc1.weight: copying a param with shape torch.Size([1536, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([2048, 512]).
# 	size mismatch for stages.2.blocks.3.mlp.fc1.bias: copying a param with shape torch.Size([1536]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for stages.2.blocks.3.mlp.fc2.weight: copying a param with shape torch.Size([384, 1536, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 2048]).
# 	size mismatch for stages.2.blocks.3.mlp.fc2.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.4.conv_dw.weight: copying a param with shape torch.Size([384, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([512, 1, 7, 7]).
# 	size mismatch for stages.2.blocks.4.conv_dw.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.4.norm.weight: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.4.norm.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.4.mlp.fc1.weight: copying a param with shape torch.Size([1536, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([2048, 512]).
# 	size mismatch for stages.2.blocks.4.mlp.fc1.bias: copying a param with shape torch.Size([1536]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for stages.2.blocks.4.mlp.fc2.weight: copying a param with shape torch.Size([384, 1536, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 2048]).
# 	size mismatch for stages.2.blocks.4.mlp.fc2.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.5.conv_dw.weight: copying a param with shape torch.Size([384, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([512, 1, 7, 7]).
# 	size mismatch for stages.2.blocks.5.conv_dw.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.5.norm.weight: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.5.norm.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.5.mlp.fc1.weight: copying a param with shape torch.Size([1536, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([2048, 512]).
# 	size mismatch for stages.2.blocks.5.mlp.fc1.bias: copying a param with shape torch.Size([1536]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for stages.2.blocks.5.mlp.fc2.weight: copying a param with shape torch.Size([384, 1536, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 2048]).
# 	size mismatch for stages.2.blocks.5.mlp.fc2.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.6.conv_dw.weight: copying a param with shape torch.Size([384, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([512, 1, 7, 7]).
# 	size mismatch for stages.2.blocks.6.conv_dw.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.6.norm.weight: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.6.norm.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.6.mlp.fc1.weight: copying a param with shape torch.Size([1536, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([2048, 512]).
# 	size mismatch for stages.2.blocks.6.mlp.fc1.bias: copying a param with shape torch.Size([1536]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for stages.2.blocks.6.mlp.fc2.weight: copying a param with shape torch.Size([384, 1536, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 2048]).
# 	size mismatch for stages.2.blocks.6.mlp.fc2.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.7.conv_dw.weight: copying a param with shape torch.Size([384, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([512, 1, 7, 7]).
# 	size mismatch for stages.2.blocks.7.conv_dw.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.7.norm.weight: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.7.norm.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.7.mlp.fc1.weight: copying a param with shape torch.Size([1536, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([2048, 512]).
# 	size mismatch for stages.2.blocks.7.mlp.fc1.bias: copying a param with shape torch.Size([1536]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for stages.2.blocks.7.mlp.fc2.weight: copying a param with shape torch.Size([384, 1536, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 2048]).
# 	size mismatch for stages.2.blocks.7.mlp.fc2.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.8.conv_dw.weight: copying a param with shape torch.Size([384, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([512, 1, 7, 7]).
# 	size mismatch for stages.2.blocks.8.conv_dw.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.8.norm.weight: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.8.norm.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.2.blocks.8.mlp.fc1.weight: copying a param with shape torch.Size([1536, 384, 1, 1]) from checkpoint, the shape in current model is torch.Size([2048, 512]).
# 	size mismatch for stages.2.blocks.8.mlp.fc1.bias: copying a param with shape torch.Size([1536]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for stages.2.blocks.8.mlp.fc2.weight: copying a param with shape torch.Size([384, 1536, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 2048]).
# 	size mismatch for stages.2.blocks.8.mlp.fc2.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.3.downsample.0.weight: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.3.downsample.0.bias: copying a param with shape torch.Size([384]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for stages.3.downsample.1.weight: copying a param with shape torch.Size([768, 384, 2, 2]) from checkpoint, the shape in current model is torch.Size([1024, 512, 2, 2]).
# 	size mismatch for stages.3.downsample.1.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.0.conv_dw.weight: copying a param with shape torch.Size([768, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([1024, 1, 7, 7]).
# 	size mismatch for stages.3.blocks.0.conv_dw.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.0.norm.weight: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.0.norm.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.0.mlp.fc1.weight: copying a param with shape torch.Size([3072, 768, 1, 1]) from checkpoint, the shape in current model is torch.Size([4096, 1024]).
# 	size mismatch for stages.3.blocks.0.mlp.fc1.bias: copying a param with shape torch.Size([3072]) from checkpoint, the shape in current model is torch.Size([4096]).
# 	size mismatch for stages.3.blocks.0.mlp.fc2.weight: copying a param with shape torch.Size([768, 3072, 1, 1]) from checkpoint, the shape in current model is torch.Size([1024, 4096]).
# 	size mismatch for stages.3.blocks.0.mlp.fc2.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.1.conv_dw.weight: copying a param with shape torch.Size([768, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([1024, 1, 7, 7]).
# 	size mismatch for stages.3.blocks.1.conv_dw.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.1.norm.weight: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.1.norm.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.1.mlp.fc1.weight: copying a param with shape torch.Size([3072, 768, 1, 1]) from checkpoint, the shape in current model is torch.Size([4096, 1024]).
# 	size mismatch for stages.3.blocks.1.mlp.fc1.bias: copying a param with shape torch.Size([3072]) from checkpoint, the shape in current model is torch.Size([4096]).
# 	size mismatch for stages.3.blocks.1.mlp.fc2.weight: copying a param with shape torch.Size([768, 3072, 1, 1]) from checkpoint, the shape in current model is torch.Size([1024, 4096]).
# 	size mismatch for stages.3.blocks.1.mlp.fc2.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.2.conv_dw.weight: copying a param with shape torch.Size([768, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([1024, 1, 7, 7]).
# 	size mismatch for stages.3.blocks.2.conv_dw.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.2.norm.weight: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.2.norm.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for stages.3.blocks.2.mlp.fc1.weight: copying a param with shape torch.Size([3072, 768, 1, 1]) from checkpoint, the shape in current model is torch.Size([4096, 1024]).
# 	size mismatch for stages.3.blocks.2.mlp.fc1.bias: copying a param with shape torch.Size([3072]) from checkpoint, the shape in current model is torch.Size([4096]).
# 	size mismatch for stages.3.blocks.2.mlp.fc2.weight: copying a param with shape torch.Size([768, 3072, 1, 1]) from checkpoint, the shape in current model is torch.Size([1024, 4096]).
# 	size mismatch for stages.3.blocks.2.mlp.fc2.bias: copying a param with shape torch.Size([768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for head.fc.weight: copying a param with shape torch.Size([2, 768]) from checkpoint, the shape in current model is torch.Size([2, 1024]).
