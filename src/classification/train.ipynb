# %%
import os
os.chdir('..')
os.chdir('..')

# %%
from src.classification.training.trainer import Trainer
from src.classification.evaluation.evaluator import Evaluator

# %%
data_root = (
    r"D:\Project\Synthetic Speech Recognizer"
    r"\datasets\raw\for-norm\for-norm"
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
trainer = Trainer(
    model_path="convnext_tiny_hnf.a2h_in1k",

    data_root=data_root,

    in_chans=1,
    num_classes=2,

    batch_size=32,
    lr=1e-3,
    weight_decay=1e-5,

    epochs=10,
)
# Out:
# Device: cuda
# AMP: True

# %%
trainer.train(
    save_path="best_model.pt",
    history_path="history.csv",
)
# Out:
# Training for up to 10 epochs on cuda
# --------------------------------------------------------------------
#  Epoch | Train Loss | Train Acc |  Val Loss |   Val Acc |     Status
# --------------------------------------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 trainer.train(
#       2     save_path="best_model.pt",
#       3     history_path="history.csv",
#       4 )
#
# File d:\Project\Synthetic Speech Recognizer\src\classification\training\trainer.py:236, in Trainer.train(self, save_path, history_path)
#     233 print(divider)
#     235 for epoch in range(1, self.epochs + 1):
# --> 236     train_loss, train_acc = self._run_epoch(
#     237         self.train_loader,
#     238         train=True
#     239     )
#     241     val_loss, val_acc = self._run_epoch(
#     242         self.val_loader,
#     243         train=False
#     244     )
#     246     history["epoch"].append(epoch)
#
# File d:\Project\Synthetic Speech Recognizer\src\classification\training\trainer.py:168, in Trainer._run_epoch(self, loader, train)
#     163 if train:
#     164     self.scaler.scale(
#     165         loss
#     166     ).backward()
# --> 168     self.scaler.stop(
#     169         self.optimizer
#     170     )
#     172     self.scaler.update()
#     174     self.scheduler.step()
#
# AttributeError: 'GradScaler' object has no attribute 'stop'

# %%
evaluator = Evaluator(
    model_path="convnext_tiny_hnf.a2h_in1k",
    weight_path="best_model.pt",

    in_chans=1,
    num_classes=2,

    batch_size=32,
)

results = evaluator.evaluate(
    data_root=data_root
)

print(results)
