# %%
import os
os.chdir('..')
os.chdir('..')

# %%
from src.classification.training.trainer import Trainer
from src.classification.evaluation.evaluator import Evaluator

# %%
data_root = r"D:\Project\Synthetic Speech Recognizer\datasets\ASVLibri"

# %%
trainer = Trainer(
    model_path="convnext_tiny_hnf.a2h_in1k",

    data_root=data_root,

    in_chans=1,
    num_classes=2,

    batch_size=32,
    lr=1e-3,
    weight_decay=1e-5,

    epochs=10,
)
# Out:
# Device: cuda
# AMP: True
# ...
# model.safetensors:   0%|          | 0.00/114M [00:00<?, ?B/s]
# d:\Project\Synthetic Speech Recognizer\src\classification\training\trainer.py:108: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(

# %%
trainer.train(
    save_path="best_model.pt",
    history_path="history.csv",
)
# Out:
# Training for up to 10 epochs on cuda
# --------------------------------------------------------------------
#  Epoch | Train Loss | Train Acc |  Val Loss |   Val Acc |     Status
# --------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 trainer.train(
#       2     save_path="best_model.pt",
#       3     history_path="history.csv",
#       4 )
#
# File d:\Project\Synthetic Speech Recognizer\src\classification\training\trainer.py:236, in Trainer.train(self, save_path, history_path)
#     233 print(divider)
#     235 for epoch in range(1, self.epochs + 1):
# --> 236     train_loss, train_acc = self._run_epoch(
#     237         self.train_loader,
#     238         train=True
#     239     )
#     241     val_loss, val_acc = self._run_epoch(
#     242         self.val_loader,
# ...

# %%
evaluator = Evaluator(
    model_path="timm/convnextv2_atto.fcmae",
    weight_path=r"D:\Project\Synthetic Speech Recognizer\models\synthetic-speech-recognizer\best_model.pt",

    in_chans=1,
    num_classes=2,

    batch_size=32,
)

results = evaluator.evaluate(
    data_root=data_root,
    split="testing"
)

print(results)
# Out:
# d:\Project\Synthetic Speech Recognizer\src\classification\evaluation\evaluator.py:58: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(
# ...

# %%
evaluator = Evaluator(
    model_path="timm/convnextv2_atto.fcmae",
    weight_path=r"D:\Project\Synthetic Speech Recognizer\models\synthetic-speech-recognizer\best_model.pt",

    in_chans=1,
    num_classes=2,

    batch_size=32,
)

results = evaluator.evaluate(
    data_root=data_root,
    split="validation"
)

print(results)
# Out:
# d:\Project\Synthetic Speech Recognizer\src\classification\evaluation\evaluator.py:58: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(
# ...
